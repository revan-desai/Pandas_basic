# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/Pandas_basic/blob/main/dataframe_AAUM_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel("/content/DS_Interview.xlsx")

# %%
df
# Out:
#     Brand  Year  Week  Sales        Unit   Avg_Price  Digital Media     TV  \
# 0       X  2022     1  17079  552.000000   30.985715        47786.0  181.0
# 1       X  2022     2  12337  402.000000   30.755334        40172.0  181.0
# 2       X  2022     3  17031  554.000000   30.754516        12016.0  219.0
# 3       X  2022     4  16879  551.000000   30.677216        28503.0  193.0
# 4       X  2022     5  17247  557.000000   30.987461        25681.0  226.0
# ..    ...   ...   ...    ...         ...         ...            ...    ...
# 307     Z  2023    48  87827  846.404913  103.764757        31525.0  128.0
# 308     Z  2023    49  92100  819.445510  112.393074        31826.0  153.0
# 309     Z  2023    50  78219  677.474989  115.456661        27643.0  289.0
# 310     Z  2023    51  97709  875.077178  111.657580        31061.0  100.0
# 311     Z  2023    52  97021  860.846822  112.704139        31250.0  278.0
#
#      Radio      OOH  Print
# 0       63  25844.0  16409
# ...

# %%
df.sort_values(by=["Brand","Year"],ascending=True,inplace=True)

# %%
df
# Out:
#     Brand  Year  Week  Sales        Unit   Avg_Price  Digital Media     TV  \
# 0       X  2022     1  17079  552.000000   30.985715        47786.0  181.0
# 1       X  2022     2  12337  402.000000   30.755334        40172.0  181.0
# 2       X  2022     3  17031  554.000000   30.754516        12016.0  219.0
# 3       X  2022     4  16879  551.000000   30.677216        28503.0  193.0
# 4       X  2022     5  17247  557.000000   30.987461        25681.0  226.0
# ..    ...   ...   ...    ...         ...         ...            ...    ...
# 307     Z  2023    48  87827  846.404913  103.764757        31525.0  128.0
# 308     Z  2023    49  92100  819.445510  112.393074        31826.0  153.0
# 309     Z  2023    50  78219  677.474989  115.456661        27643.0  289.0
# 310     Z  2023    51  97709  875.077178  111.657580        31061.0  100.0
# 311     Z  2023    52  97021  860.846822  112.704139        31250.0  278.0
#
#      Radio      OOH  Print
# 0       63  25844.0  16409
# ...

# %%
df_sales_per_year=df.groupby("Year")["Sales"].sum()

# %%
total_sales=df_sales_per_year[2022]+df_sales_per_year[2023]

total_sales
# Out:
# 17472762

# %%
df_sales_per_year[2023]
# Out:
# 8710732

# %%
df_sales_per_brand_year=df.groupby(["Brand","Year"])["Radio"].sum()

# %%
df_sales_per_brand_year["Z"][2023]   #Brand Z  total radio sales in year 2023
# Out:
# 2018

# %% [markdown]
# ### Growth Rate

# %%
#growth_rate=(current_year_sale-previous_year_sale/previous_year_sale)*100

# %%
df_yearwise_sales=df.groupby("Year")["Sales"].sum()

# %%
((df_yearwise_sales[2023]-df_yearwise_sales[2022])/df_yearwise_sales[2022])*100
# Out:
# -0.5854579361175436

# %%
df.isna().sum()
# Out:
# Brand             0
# Year              0
# Week              0
# Sales             0
# Unit              0
# Avg_Price         0
# Digital Media    65
# TV               11
# Radio             0
# OOH               6
# Print             0
# dtype: int64

# %%
res=df.isna().mean()     #5/15

res
# Out:
# Brand            0.000000
# Year             0.000000
# Week             0.000000
# Sales            0.000000
# Unit             0.000000
# Avg_Price        0.000000
# Digital Media    0.208333
# TV               0.035256
# Radio            0.000000
# OOH              0.019231
# Print            0.000000
# dtype: float64

# %%
df_filtered=df.loc[:,res<0.2]   # all rows and all columns where null values less than 0.20 ie. 20%

df_filtered
# Out:
#     Brand  Year  Week  Sales        Unit   Avg_Price     TV  Radio      OOH  \
# 0       X  2022     1  17079  552.000000   30.985715  181.0     63  25844.0
# 1       X  2022     2  12337  402.000000   30.755334  181.0     58  33848.0
# 2       X  2022     3  17031  554.000000   30.754516  219.0     57  39961.0
# 3       X  2022     4  16879  551.000000   30.677216  193.0     72  32309.0
# 4       X  2022     5  17247  557.000000   30.987461  226.0     72  38084.0
# ..    ...   ...   ...    ...         ...         ...    ...    ...      ...
# 307     Z  2023    48  87827  846.404913  103.764757  128.0     26  40180.0
# 308     Z  2023    49  92100  819.445510  112.393074  153.0     48  39130.0
# 309     Z  2023    50  78219  677.474989  115.456661  289.0     26  40716.0
# 310     Z  2023    51  97709  875.077178  111.657580  100.0     26  46150.0
# 311     Z  2023    52  97021  860.846822  112.704139  278.0     29  43492.0
#
#      Print
# 0    16409
# 1    19235
# 2    10770
# ...

# %%
df
# Out:
#     Brand  Year  Week  Sales        Unit   Avg_Price  Digital Media     TV  \
# 0       X  2022     1  17079  552.000000   30.985715        47786.0  181.0
# 1       X  2022     2  12337  402.000000   30.755334        40172.0  181.0
# 2       X  2022     3  17031  554.000000   30.754516        12016.0  219.0
# 3       X  2022     4  16879  551.000000   30.677216        28503.0  193.0
# 4       X  2022     5  17247  557.000000   30.987461        25681.0  226.0
# ..    ...   ...   ...    ...         ...         ...            ...    ...
# 307     Z  2023    48  87827  846.404913  103.764757        31525.0  128.0
# 308     Z  2023    49  92100  819.445510  112.393074        31826.0  153.0
# 309     Z  2023    50  78219  677.474989  115.456661        27643.0  289.0
# 310     Z  2023    51  97709  875.077178  111.657580        31061.0  100.0
# 311     Z  2023    52  97021  860.846822  112.704139        31250.0  278.0
#
#      Radio      OOH  Print
# 0       63  25844.0  16409
# ...

# %%
df["Brand"].nunique()
# Out:
# 3

# %%
df1=df.drop_duplicates(["Brand"],keep="last")

# %%
df1.sort_values(by=["Unit"])
# Out:
#     Brand  Year  Week  Sales         Unit   Avg_Price  Digital Media     TV  \
# 103     X  2023    52  18322   595.000000   30.818344    29779.65587   99.0
# 311     Z  2023    52  97021   860.846822  112.704139    31250.00000  278.0
# 207     Y  2023    52  72185  1170.000000   61.742447    31142.00000  242.0
#
#      Radio      OOH  Print
# 103     53  34295.0  20845
# 311     29  43492.0  64145
# 207     33  49608.0  24184

# %%
mask1=df["Brand"]=="X"
mask2=df["Year"]==2023


df[mask1&mask2].head()
# Out:
#    Brand  Year  Week  Sales   Unit  Avg_Price  Digital Media     TV  Radio  \
# 52     X  2023     1  24815  819.0  30.332514        11990.0   86.0     56
# 53     X  2023     2  13976  456.0  30.652541        20407.0  172.0     57
# 54     X  2023     3  14731  490.0  30.093291        38181.0  148.0     72
# 55     X  2023     4  21920  723.0  30.319385        46234.0  170.0     62
# 56     X  2023     5  16039  531.0  30.216093        37702.0  132.0     71
#
#         OOH  Print
# 52  12735.0  24343
# 53  16835.0  19759
# 54  25280.0  10121
# 55  26156.0  17345
# 56  13791.0  25770

# %%
df["Digital Media"].fillna(df["Digital Media"].mean(),inplace=True)

df.head(3)
# Out:
#   Brand  Year  Week  Sales   Unit  Avg_Price  Digital Media     TV  Radio  \
# 0     X  2022     1  17079  552.0  30.985715        47786.0  181.0     63
# 1     X  2022     2  12337  402.0  30.755334        40172.0  181.0     58
# 2     X  2022     3  17031  554.0  30.754516        12016.0  219.0     57
#
#        OOH  Print
# 0  25844.0  16409
# 1  33848.0  19235
# 2  39961.0  10770

# %%
delivery=pd.read_csv("")

delivery.groupby("batsman")["batsman_runs"].sum().sort_values(by="batsman_runs",ascending=False)
