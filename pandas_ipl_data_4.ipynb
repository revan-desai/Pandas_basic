# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/Pandas_basic/blob/main/pandas_ipl_data_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

ipldata=pd.read_csv('/content/iplmatches.csv')

ipldata[['city','season']]
# Out:
#           city  season
# 0    Hyderabad    2017
# 1         Pune    2017
# 2       Rajkot    2017
# 3       Indore    2017
# 4    Bangalore    2017
# ..         ...     ...
# 631     Raipur    2016
# 632  Bangalore    2016
# 633      Delhi    2016
# 634      Delhi    2016
# 635  Bangalore    2016
#
# [636 rows x 2 columns]

# %%
ipldata[ipldata['city']=='Mumbai']['season']  # if want more columns then [['season','winner']]
# Out:
#      season                   winner
# 6      2017           Mumbai Indians
# 9      2017           Mumbai Indians
# 15     2017           Mumbai Indians
# 23     2017           Mumbai Indians
# 27     2017   Rising Pune Supergiant
# ..      ...                      ...
# 572    2015           Mumbai Indians
# 576    2016  Rising Pune Supergiants
# 584    2016            Gujarat Lions
# 589    2016           Mumbai Indians
# 599    2016           Mumbai Indians
#
# [85 rows x 2 columns]

# %%
city=ipldata.groupby('city')

city.size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
city.get_group('Chennai')
# Out:
#       id  season     city        date                        team1  \
# 66    67    2008  Chennai  2008-04-23          Chennai Super Kings
# 70    71    2008  Chennai  2008-04-26        Kolkata Knight Riders
# 78    79    2008  Chennai  2008-05-02          Chennai Super Kings
# 84    85    2008  Chennai  2008-05-06          Chennai Super Kings
# 90    91    2008  Chennai  2008-05-10          Chennai Super Kings
# 106  107    2008  Chennai  2008-05-21  Royal Challengers Bangalore
# 109  110    2008  Chennai  2008-05-24             Rajasthan Royals
# 178  179    2010  Chennai  2010-03-14              Deccan Chargers
# 189  190    2010  Chennai  2010-03-21              Kings XI Punjab
# 201  202    2010  Chennai  2010-03-31  Royal Challengers Bangalore
# 205  206    2010  Chennai  2010-04-03          Chennai Super Kings
# 210  211    2010  Chennai  2010-04-06          Chennai Super Kings
# 221  222    2010  Chennai  2010-04-13        Kolkata Knight Riders
# ...

# %%
city.sum()
# Out:
# <ipython-input-86-92897a7359df>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city.sum()
#                    id  season  dl_applied  win_by_runs  win_by_wickets  \
# city
# Abu Dhabi        3263   14098           0          157              16
# Ahmedabad        4863   24156           0          180              38
# Bangalore       22299  132861           3         1263             232
# Bloemfontein      326    4018           0           14               6
# Cape Town         858   14063           1          145              18
# Centurion        1842   24108           1           81              49
# Chandigarh      15325   92582           0          576             167
# Chennai         15096   96554           0          715             111
# ...

# %%
city['win_by_runs'].mean()
# Out:
# city
# Abu Dhabi         22.428571
# Ahmedabad         15.000000
# Bangalore         19.136364
# Bloemfontein       7.000000
# Cape Town         20.714286
# Centurion          6.750000
# Chandigarh        12.521739
# Chennai           14.895833
# Cuttack           10.428571
# Delhi             14.600000
# Dharamsala        31.000000
# Durban            10.600000
# East London       29.000000
# Hyderabad          9.918367
# Indore             0.000000
# Jaipur            13.939394
# Johannesburg       3.125000
# Kanpur             0.000000
# Kimberley         17.666667
# Kochi             22.000000
# Kolkata            9.622951
# Mumbai            12.964706
# Nagpur             5.000000
# Port Elizabeth    28.571429
# Pune              17.031250
# Raipur             3.500000
# Rajkot             7.000000
# Ranchi             5.857143
# Sharjah           12.333333
# Visakhapatnam     25.636364
# Name: win_by_runs, dtype: float64

# %%
city['win_by_runs'].max()
# Out:
# city
# Abu Dhabi          93
# Ahmedabad          62
# Bangalore         144
# Bloemfontein       14
# Cape Town          75
# Centurion          38
# Chandigarh         76
# Chennai            97
# Cuttack            44
# Delhi             146
# Dharamsala        111
# Durban             78
# East London        78
# Hyderabad          77
# Indore              0
# Jaipur             87
# Johannesburg       18
# Kanpur              0
# Kimberley          53
# Kochi              55
# Kolkata            82
# Mumbai            105
# Nagpur             13
# Port Elizabeth     92
# Pune               97
# Raipur             15
# Rajkot             26
# Ranchi             34
# Sharjah            72
# Visakhapatnam      85
# Name: win_by_runs, dtype: int64

# %%
city['win_by_wickets'].max().sort_values(ascending=False)
# Out:
# city
# Jaipur            10
# Chandigarh        10
# Mumbai            10
# Delhi             10
# Rajkot            10
# Cape Town         10
# Bangalore         10
# Chennai            9
# Cuttack            9
# Durban             9
# Hyderabad          9
# Ahmedabad          9
# Johannesburg       9
# Pune               9
# Kolkata            9
# Centurion          8
# Sharjah            8
# Indore             8
# Kanpur             8
# Raipur             7
# Port Elizabeth     7
# Visakhapatnam      7
# Kochi              7
# Kimberley          7
# East London        7
# Nagpur             6
# Dharamsala         6
# Ranchi             6
# Bloemfontein       6
# Abu Dhabi          6
# Name: win_by_wickets, dtype: int64
