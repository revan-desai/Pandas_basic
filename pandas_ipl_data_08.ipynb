# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/Pandas_basic/blob/main/pandas_ipl_data_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data={'Name':['nitesh','anu','mukesh','suresh','rajiv','john','vicky'],'Gender':['M','F','M','M','M','M','M'] ,'City':['mumbai','pune','delhi','kolkata','chennai','mumbai','pune'] ,
      'Frequency':['daily','weekly','once','weekly','monthly','daily','monthly'] ,'item':['burger','sandwitch','pizza','rasgulla','idli','burger','pizza'], 'spends':[150,80,200,40,50,120,350]}

food=pd.DataFrame(data)

food
# Out:
#      Name Gender     City Frequency       item  spends
# 0  nitesh      M   mumbai     daily     burger     150
# 1     anu      F     pune    weekly  sandwitch      80
# 2  mukesh      M    delhi      once      pizza     200
# 3  suresh      M  kolkata    weekly   rasgulla      40
# 4   rajiv      M  chennai   monthly       idli      50
# 5    john      M   mumbai     daily     burger     120
# 6   vicky      M     pune   monthly      pizza     350

# %%
food.pivot_table(index=['City'],columns=['item'],values='spends',aggfunc='sum')
# Out:
# item     burger  idli  pizza  rasgulla  sandwitch
# City
# chennai     NaN  50.0    NaN       NaN        NaN
# delhi       NaN   NaN  200.0       NaN        NaN
# kolkata     NaN   NaN    NaN      40.0        NaN
# mumbai    270.0   NaN    NaN       NaN        NaN
# pune        NaN   NaN  350.0       NaN       80.0

# %%
food.pivot_table(index=['City','Gender'],columns=['item'],values='spends',aggfunc='mean')
# Out:
# item            burger  idli  pizza  rasgulla  sandwitch
# City    Gender
# chennai M          NaN  50.0    NaN       NaN        NaN
# delhi   M          NaN   NaN  200.0       NaN        NaN
# kolkata M          NaN   NaN    NaN      40.0        NaN
# mumbai  M        135.0   NaN    NaN       NaN        NaN
# pune    F          NaN   NaN    NaN       NaN       80.0
#         M          NaN   NaN  350.0       NaN        NaN

# %%
food.pivot_table(index=['City','Gender'],columns=['item','Name'],values='spends',aggfunc='mean')
# Out:
# item           burger         idli  pizza        rasgulla sandwitch
# Name             john nitesh rajiv mukesh  vicky   suresh       anu
# City    Gender
# chennai M         NaN    NaN  50.0    NaN    NaN      NaN       NaN
# delhi   M         NaN    NaN   NaN  200.0    NaN      NaN       NaN
# kolkata M         NaN    NaN   NaN    NaN    NaN     40.0       NaN
# mumbai  M       120.0  150.0   NaN    NaN    NaN      NaN       NaN
# pune    F         NaN    NaN   NaN    NaN    NaN      NaN      80.0
#         M         NaN    NaN   NaN    NaN  350.0      NaN       NaN
