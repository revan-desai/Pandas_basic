# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/Pandas_basic/blob/main/eda_01_understanding_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

data=pd.read_csv('/content/student.csv')

data.head(3)
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
data.tail(3)
# Out:
#     id        name  class  mark  gender
# 32  33   Kenn Rein    Six    96  female
# 33  34    Gain Toe  Seven    69    male
# 34  35  Rows Noump    Six    88  female

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   35 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
data.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
data.shape                    # (rows,columns)
#np.shape(data)              # (rows,columns)
# Out:
# (35, 5)

# %% [markdown]
# ## columns in dataframe

# %%
data.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
data.nunique()     # use parenthesis   # number of unique values
# Out:
# id        35
# name      35
# class      8
# mark      17
# gender     2
# dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data.isnull().sum()
# Out:
# id      0
# name    0
# mark    0
# dtype: int64

# %% [markdown]
# ## changing the data type of column....if required
#
# ### ..here we are changing data type of mark column from int to float

# %%
data['mark']=data['mark'].astype(float)    # while making changing into any column make sure you write same column on left side of equal operator
                                           # this is wrong way--> ...data=data['mark'].astype(float)
data.head(3)
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four  75.0  female
# 1   2  Max Ruin  Three  85.0    male
# 2   3    Arnold  Three  55.0    male
